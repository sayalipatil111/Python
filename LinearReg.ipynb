# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Salary_Data_1 (1).csv')
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
pip install scikit-learn
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the 'C:\Users\Sanket\AppData\Local\Programs\Python\Python37\python.exe -m pip install --upgrade pip' command.
# ...
#      ---------------------------------------- 7.1/7.1 MB 3.7 MB/s eta 0:00:00
# ...
#      -------------------------------------- 302.2/302.2 KB 9.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 34.1/34.1 MB 7.2 MB/s eta 0:00:00
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
X= df[['YearsExperience']]   # skill, experience  Independent variable
y= df['Salary'] # dependant

# %%
plt.figure(figsize=(5,5))
plt.xlim(0,12) 
plt.ylim(0,120000)
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.scatter(X,y)

# %%
model= LinearRegression()  # empty model
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 25792.20019866871

# %%
yp= model.predict([[7]])   # prediction 
print(yp)
# Out:
# [91941.93644885]
# C:\Users\Sanket\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"

# %%
yp=model.predict(X)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
mean_absolute_error(y,yp)
# Out:
# 4644.2012894435375

# %%
mean_squared_error(y,yp)
# Out:
# 31270951.722280968

# %%
r2_score(y,yp)
# Out:
# 0.9569566641435086
